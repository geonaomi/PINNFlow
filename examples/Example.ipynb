# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PINNFlow import *
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from sklearn.metrics import mean_squared_error
import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Example: Westward Flow under the Atlantic
#
# This is some example code to find the horizontal flow at the CMB in a region underneath the Atlantic.

# %% [markdown]
# The following code snippet allows you to train on a GPU, if you have one, or else defaults to a CPU. GPU training is faster, but CPUs can still be used if this is not available.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Loading in data
#
# For this example, we are wanting to study an area in the Atlantic, at spherical harmonic degree 13, on the 1st January 2024.
#
# To do this, we will use the CHAOS-8.1 model, but any Geomagnetic Field model can be used if it is in the same format. We then supply the path to the MAT-file, and then use the data_generator function to calculate the values on a grid.

# %%
mat_file = "CHAOS-8.1.mat"

# %%
radius_data, phi_data, theta_data, Br_data, Br_dot_data, Br_div_theta_data , Br_div_phi_data = data_generator(mat_file, 2024, 1, 1, 13,  dy = 30 , dx = 55, clat1 = 55,clat2 = 85, long1 = -50, long2 = 5)

# %%
plt.rcParams.update({'font.size': 16})
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2, figsize=(15,10))
plot1 = ax1.scatter(phi_data*180/np.pi, 90-theta_data*180/np.pi,c=Br_data,cmap = 'bwr')
plot2 = ax2.scatter(phi_data*180/np.pi, 90-theta_data*180/np.pi, c=Br_dot_data,cmap = 'bwr')
plt.colorbar(plot1, ax = ax1, label = '$\mu$ T')
plt.colorbar(plot2, ax = ax2, label = '$\mu$ T/0.1yr')
plt.tight_layout(pad=3)
ax1.set_title('Magnetic field (Br) \n')
ax1.set_xlabel('Longitude')
ax1.set_ylabel('Latitude')
ax2.set_title('Rate of change of the magnetic field, SV \n')
ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')
plot3 = ax3.scatter(phi_data*180/np.pi, 90-theta_data*180/np.pi, c=Br_div_theta_data,cmap = 'bwr')
plot4 = ax4.scatter(phi_data*180/np.pi, 90-theta_data*180/np.pi, c=Br_div_phi_data,cmap = 'bwr')
plt.colorbar(plot3, ax = ax3, label = '$\mu$ T/km')
plt.colorbar(plot4, ax = ax4, label = '$\mu$ T/km')
plt.tight_layout(pad=3)
ax3.set_title('Derivative of Br with respect to latitude \n')
ax3.set_xlabel('Longitude')
ax3.set_ylabel('Latitude')
ax4.set_title('Derivative of Br with respect to longitude \n')
ax4.set_xlabel('Longitude')
ax4.set_ylabel('Latitude')
# Out:
# Text(784.8402777777776, 0.5, 'Latitude')

# %% [markdown]
# PyTorch requires that each of the input are flattened and in torch.Tensor format, so we do that:

# %%
theta = theta_data.flatten()[:,None]
phi = phi_data.flatten()[:,None]
radius = 3485*np.ones(theta.shape)
print("theta shape: ", theta.shape, ",phi shape: ", phi.shape)
print("sv shape: ", Br_dot_data.shape)
PHI,THETA = np.meshgrid(phi, theta)

coord =  np.hstack((phi.flatten()[:,None], theta.flatten()[:,None])) 
sv_star = Br_dot_data.flatten()[:, None]
br_star = Br_data.flatten()[:, None]
horiz_theta_star = Br_div_theta_data.flatten()[:, None]
horiz_phi_star = Br_div_phi_data.flatten()[:, None]
print("Coord shape: ", coord.shape)
print("SV_STAR shape: ", sv_star.shape)
# Out:
# theta shape:  (1650, 1) ,phi shape:  (1650, 1)
# sv shape:  (30, 55)
# Coord shape:  (1650, 2)
# SV_STAR shape:  (1650, 1)

# %%
radius_tf = torch.tensor(radius, requires_grad=True).float()
theta_tf = torch.tensor(theta, requires_grad=True).float()
phi_tf = torch.tensor(phi, requires_grad=True).float()
br_tf = torch.tensor(br_star, requires_grad=True).float()
sv_tf = torch.tensor(sv_star, requires_grad=True).float()
horiz_theta_tf = torch.tensor(horiz_theta_star, requires_grad=True).float()
horiz_phi_tf = torch.tensor(horiz_phi_star, requires_grad=True).float()

# %% [markdown]
# ## Defining Models
#
# We define the blank model from the layers and the upper and lower bound for the coordinate system. The model weights are initialised using Xavier Initialisation.

# %%
#Layers for NN, has to start and end with 2 for (theta, phi)
layers =[2,40, 40, 40, 40, 40, 40, 40, 40, 2]

# %%
lb = coord.min(0) #Lower Bound for coordinate system 
ub = coord.max(0) #Upper Bound for coordinate system

# %%
model = NeuralNet(layers, lb, ub) #Defining NN model for T, P

# %% [markdown]
# ## Training
# We define the number of training iterations, and empty arrays to record the loss:

# %%
Train_iterations = 10_000 #can be changed, value used in paper is 100_000 to ensure convergence

loss_record = np.zeros(Train_iterations) #Total Loss
loss_data_record = np.zeros(Train_iterations) #SV Loss
loss_flows_record = np.zeros(Train_iterations) #Flow Constraint Loss

# %%
# Calling Training function
train(Train_iterations, "model_name", radius_tf, phi_tf, theta_tf, sv_tf, horiz_theta_tf, horiz_phi_tf,br_tf,  model, loss_data_record, loss_flows_record, loss_record)
# Out:
# It: 0, Total Loss: 3.536e+00, SV Loss: 3.527e+00, Flow Loss: 8.554e-03, Time: 0.12
# It: 50, Total Loss: 5.194e-02, SV Loss: 5.152e-02, Flow Loss: 4.152e-04, Time: 4.66
# Loss Improved, Saving Model
# It: 100, Total Loss: 3.548e-02, SV Loss: 3.491e-02, Flow Loss: 5.743e-04, Time: 3.98
# Loss Improved, Saving Model
# It: 150, Total Loss: 2.617e-02, SV Loss: 2.528e-02, Flow Loss: 8.949e-04, Time: 4.42
# Loss Improved, Saving Model
# It: 200, Total Loss: 2.141e-02, SV Loss: 2.025e-02, Flow Loss: 1.151e-03, Time: 3.56
# Loss Improved, Saving Model
# It: 250, Total Loss: 1.694e-02, SV Loss: 1.556e-02, Flow Loss: 1.386e-03, Time: 4.46
# Loss Improved, Saving Model
# It: 300, Total Loss: 1.334e-02, SV Loss: 1.166e-02, Flow Loss: 1.671e-03, Time: 4.60
# Loss Improved, Saving Model
# It: 350, Total Loss: 1.185e-02, SV Loss: 1.023e-02, Flow Loss: 1.625e-03, Time: 5.01
# Loss Improved, Saving Model
# It: 400, Total Loss: 1.117e-02, SV Loss: 9.580e-03, Flow Loss: 1.586e-03, Time: 4.42
# Loss Improved, Saving Model
# It: 450, Total Loss: 1.072e-02, SV Loss: 9.139e-03, Flow Loss: 1.584e-03, Time: 4.87
# Loss Improved, Saving Model
# It: 500, Total Loss: 1.036e-02, SV Loss: 8.761e-03, Flow Loss: 1.598e-03, Time: 4.83
# Loss Improved, Saving Model
# It: 550, Total Loss: 1.003e-02, SV Loss: 8.407e-03, Flow Loss: 1.619e-03, Time: 4.95
# Loss Improved, Saving Model
# It: 600, Total Loss: 9.702e-03, SV Loss: 8.061e-03, Flow Loss: 1.641e-03, Time: 5.13
# Loss Improved, Saving Model
# It: 650, Total Loss: 9.382e-03, SV Loss: 7.719e-03, Flow Loss: 1.664e-03, Time: 4.52
# Loss Improved, Saving Model
# It: 700, Total Loss: 9.063e-03, SV Loss: 7.377e-03, Flow Loss: 1.687e-03, Time: 3.84
# Loss Improved, Saving Model
# It: 750, Total Loss: 8.750e-03, SV Loss: 7.040e-03, Flow Loss: 1.710e-03, Time: 4.77
# Loss Improved, Saving Model
# It: 800, Total Loss: 8.452e-03, SV Loss: 6.716e-03, Flow Loss: 1.736e-03, Time: 4.47
# Loss Improved, Saving Model
# It: 850, Total Loss: 8.182e-03, SV Loss: 6.418e-03, Flow Loss: 1.764e-03, Time: 4.60
# Loss Improved, Saving Model
# It: 900, Total Loss: 7.946e-03, SV Loss: 6.149e-03, Flow Loss: 1.797e-03, Time: 4.49
# Loss Improved, Saving Model
# It: 950, Total Loss: 7.739e-03, SV Loss: 5.907e-03, Flow Loss: 1.832e-03, Time: 4.78
# Loss Improved, Saving Model
# It: 1000, Total Loss: 7.554e-03, SV Loss: 5.686e-03, Flow Loss: 1.868e-03, Time: 4.95
# Loss Improved, Saving Model
# It: 1050, Total Loss: 7.383e-03, SV Loss: 5.482e-03, Flow Loss: 1.901e-03, Time: 3.59
# Loss Improved, Saving Model
# It: 1100, Total Loss: 7.219e-03, SV Loss: 5.289e-03, Flow Loss: 1.930e-03, Time: 4.01
# Loss Improved, Saving Model
# It: 1150, Total Loss: 7.059e-03, SV Loss: 5.105e-03, Flow Loss: 1.953e-03, Time: 4.89
# Loss Improved, Saving Model
# It: 1200, Total Loss: 6.897e-03, SV Loss: 4.925e-03, Flow Loss: 1.972e-03, Time: 4.36
# Loss Improved, Saving Model
# It: 1250, Total Loss: 6.732e-03, SV Loss: 4.747e-03, Flow Loss: 1.985e-03, Time: 4.93
# Loss Improved, Saving Model
# It: 1300, Total Loss: 6.562e-03, SV Loss: 4.571e-03, Flow Loss: 1.991e-03, Time: 3.88
# Loss Improved, Saving Model
# It: 1350, Total Loss: 6.388e-03, SV Loss: 4.399e-03, Flow Loss: 1.989e-03, Time: 3.77
# Loss Improved, Saving Model
# It: 1400, Total Loss: 6.215e-03, SV Loss: 4.236e-03, Flow Loss: 1.978e-03, Time: 4.36
# Loss Improved, Saving Model
# It: 1450, Total Loss: 6.066e-03, SV Loss: 4.117e-03, Flow Loss: 1.949e-03, Time: 4.08
# Loss Improved, Saving Model
# It: 1500, Total Loss: 5.969e-03, SV Loss: 4.010e-03, Flow Loss: 1.959e-03, Time: 4.78
# Loss Improved, Saving Model
# It: 1550, Total Loss: 5.789e-03, SV Loss: 3.876e-03, Flow Loss: 1.913e-03, Time: 5.09
# Loss Improved, Saving Model
# It: 1600, Total Loss: 5.644e-03, SV Loss: 3.771e-03, Flow Loss: 1.873e-03, Time: 4.40
# Loss Improved, Saving Model
# It: 1650, Total Loss: 5.613e-03, SV Loss: 3.748e-03, Flow Loss: 1.865e-03, Time: 4.27
# Loss Improved, Saving Model
# It: 1700, Total Loss: 5.453e-03, SV Loss: 3.635e-03, Flow Loss: 1.817e-03, Time: 4.00
# Loss Improved, Saving Model
# It: 1750, Total Loss: 5.304e-03, SV Loss: 3.536e-03, Flow Loss: 1.768e-03, Time: 4.22
# Loss Improved, Saving Model
# It: 1800, Total Loss: 5.161e-03, SV Loss: 3.444e-03, Flow Loss: 1.717e-03, Time: 4.65
# Loss Improved, Saving Model
# It: 1850, Total Loss: 6.359e-03, SV Loss: 4.615e-03, Flow Loss: 1.743e-03, Time: 3.71
# It: 1900, Total Loss: 5.169e-03, SV Loss: 3.482e-03, Flow Loss: 1.686e-03, Time: 4.76
# It: 1950, Total Loss: 4.992e-03, SV Loss: 3.361e-03, Flow Loss: 1.631e-03, Time: 4.40
# Loss Improved, Saving Model
# It: 2000, Total Loss: 4.869e-03, SV Loss: 3.288e-03, Flow Loss: 1.581e-03, Time: 4.93
# Loss Improved, Saving Model
# It: 2050, Total Loss: 4.777e-03, SV Loss: 3.232e-03, Flow Loss: 1.545e-03, Time: 4.22
# Loss Improved, Saving Model
# It: 2100, Total Loss: 4.704e-03, SV Loss: 3.187e-03, Flow Loss: 1.518e-03, Time: 4.08
# Loss Improved, Saving Model
# It: 2150, Total Loss: 4.643e-03, SV Loss: 3.147e-03, Flow Loss: 1.496e-03, Time: 4.21
# Loss Improved, Saving Model
# It: 2200, Total Loss: 4.588e-03, SV Loss: 3.110e-03, Flow Loss: 1.478e-03, Time: 4.25
# Loss Improved, Saving Model
# It: 2250, Total Loss: 4.538e-03, SV Loss: 3.077e-03, Flow Loss: 1.461e-03, Time: 4.64
# Loss Improved, Saving Model
# It: 2300, Total Loss: 5.274e-03, SV Loss: 3.881e-03, Flow Loss: 1.393e-03, Time: 4.29
# It: 2350, Total Loss: 4.544e-03, SV Loss: 3.098e-03, Flow Loss: 1.446e-03, Time: 4.35
# It: 2400, Total Loss: 4.419e-03, SV Loss: 3.005e-03, Flow Loss: 1.414e-03, Time: 4.99
# Loss Improved, Saving Model
# It: 2450, Total Loss: 4.372e-03, SV Loss: 2.979e-03, Flow Loss: 1.393e-03, Time: 4.12
# Loss Improved, Saving Model
# It: 2500, Total Loss: 4.330e-03, SV Loss: 2.951e-03, Flow Loss: 1.379e-03, Time: 4.93
# Loss Improved, Saving Model
# It: 2550, Total Loss: 4.290e-03, SV Loss: 2.922e-03, Flow Loss: 1.367e-03, Time: 4.90
# Loss Improved, Saving Model
# It: 2600, Total Loss: 4.249e-03, SV Loss: 2.893e-03, Flow Loss: 1.357e-03, Time: 4.69
# Loss Improved, Saving Model
# It: 2650, Total Loss: 4.209e-03, SV Loss: 2.860e-03, Flow Loss: 1.349e-03, Time: 4.71
# Loss Improved, Saving Model
# It: 2700, Total Loss: 4.352e-03, SV Loss: 2.996e-03, Flow Loss: 1.356e-03, Time: 4.75
# It: 2750, Total Loss: 4.142e-03, SV Loss: 2.807e-03, Flow Loss: 1.335e-03, Time: 4.09
# Loss Improved, Saving Model
# It: 2800, Total Loss: 4.097e-03, SV Loss: 2.766e-03, Flow Loss: 1.332e-03, Time: 4.45
# Loss Improved, Saving Model
# It: 2850, Total Loss: 4.056e-03, SV Loss: 2.729e-03, Flow Loss: 1.328e-03, Time: 4.81
# Loss Improved, Saving Model
# It: 2900, Total Loss: 4.016e-03, SV Loss: 2.693e-03, Flow Loss: 1.323e-03, Time: 4.94
# Loss Improved, Saving Model
# It: 2950, Total Loss: 3.976e-03, SV Loss: 2.657e-03, Flow Loss: 1.319e-03, Time: 4.32
# Loss Improved, Saving Model
# It: 3000, Total Loss: 4.000e-03, SV Loss: 2.650e-03, Flow Loss: 1.350e-03, Time: 4.06
# It: 3050, Total Loss: 3.916e-03, SV Loss: 2.600e-03, Flow Loss: 1.316e-03, Time: 4.50
# Loss Improved, Saving Model
# It: 3100, Total Loss: 3.873e-03, SV Loss: 2.564e-03, Flow Loss: 1.309e-03, Time: 4.89
# Loss Improved, Saving Model
# It: 3150, Total Loss: 3.835e-03, SV Loss: 2.530e-03, Flow Loss: 1.304e-03, Time: 4.06
# Loss Improved, Saving Model
# It: 3200, Total Loss: 3.797e-03, SV Loss: 2.497e-03, Flow Loss: 1.300e-03, Time: 4.20
# Loss Improved, Saving Model
# It: 3250, Total Loss: 3.760e-03, SV Loss: 2.463e-03, Flow Loss: 1.297e-03, Time: 4.95
# Loss Improved, Saving Model
# It: 3300, Total Loss: 4.645e-03, SV Loss: 3.268e-03, Flow Loss: 1.377e-03, Time: 4.95
# It: 3350, Total Loss: 3.705e-03, SV Loss: 2.404e-03, Flow Loss: 1.300e-03, Time: 4.91
# Loss Improved, Saving Model
# It: 3400, Total Loss: 3.662e-03, SV Loss: 2.366e-03, Flow Loss: 1.295e-03, Time: 4.10
# Loss Improved, Saving Model
# It: 3450, Total Loss: 3.624e-03, SV Loss: 2.329e-03, Flow Loss: 1.294e-03, Time: 4.14
# Loss Improved, Saving Model
# It: 3500, Total Loss: 3.587e-03, SV Loss: 2.293e-03, Flow Loss: 1.294e-03, Time: 4.34
# Loss Improved, Saving Model
# It: 3550, Total Loss: 3.549e-03, SV Loss: 2.256e-03, Flow Loss: 1.293e-03, Time: 4.12
# Loss Improved, Saving Model
# It: 3600, Total Loss: 3.512e-03, SV Loss: 2.218e-03, Flow Loss: 1.294e-03, Time: 4.26
# Loss Improved, Saving Model
# It: 3650, Total Loss: 3.515e-03, SV Loss: 2.213e-03, Flow Loss: 1.302e-03, Time: 4.38
# It: 3700, Total Loss: 3.449e-03, SV Loss: 2.152e-03, Flow Loss: 1.297e-03, Time: 4.03
# Loss Improved, Saving Model
# It: 3750, Total Loss: 3.411e-03, SV Loss: 2.114e-03, Flow Loss: 1.296e-03, Time: 4.24
# Loss Improved, Saving Model
# It: 3800, Total Loss: 3.375e-03, SV Loss: 2.078e-03, Flow Loss: 1.296e-03, Time: 4.05
# Loss Improved, Saving Model
# It: 3850, Total Loss: 3.340e-03, SV Loss: 2.044e-03, Flow Loss: 1.296e-03, Time: 4.69
# Loss Improved, Saving Model
# It: 3900, Total Loss: 3.307e-03, SV Loss: 2.011e-03, Flow Loss: 1.296e-03, Time: 4.19
# Loss Improved, Saving Model
# It: 3950, Total Loss: 3.722e-03, SV Loss: 2.423e-03, Flow Loss: 1.299e-03, Time: 4.29
# It: 4000, Total Loss: 3.271e-03, SV Loss: 1.968e-03, Flow Loss: 1.303e-03, Time: 4.00
# Loss Improved, Saving Model
# It: 4050, Total Loss: 3.228e-03, SV Loss: 1.933e-03, Flow Loss: 1.295e-03, Time: 4.63
# Loss Improved, Saving Model
# It: 4100, Total Loss: 3.200e-03, SV Loss: 1.904e-03, Flow Loss: 1.296e-03, Time: 3.98
# Loss Improved, Saving Model
# It: 4150, Total Loss: 3.172e-03, SV Loss: 1.877e-03, Flow Loss: 1.295e-03, Time: 4.56
# Loss Improved, Saving Model
# It: 4200, Total Loss: 3.146e-03, SV Loss: 1.852e-03, Flow Loss: 1.294e-03, Time: 3.71
# Loss Improved, Saving Model
# It: 4250, Total Loss: 3.446e-03, SV Loss: 2.177e-03, Flow Loss: 1.269e-03, Time: 4.06
# It: 4300, Total Loss: 3.159e-03, SV Loss: 1.895e-03, Flow Loss: 1.263e-03, Time: 4.30
# It: 4350, Total Loss: 3.084e-03, SV Loss: 1.792e-03, Flow Loss: 1.293e-03, Time: 4.83
# Loss Improved, Saving Model
# It: 4400, Total Loss: 3.061e-03, SV Loss: 1.771e-03, Flow Loss: 1.290e-03, Time: 4.17
# Loss Improved, Saving Model
# It: 4450, Total Loss: 3.830e-03, SV Loss: 2.462e-03, Flow Loss: 1.368e-03, Time: 4.31
# It: 4500, Total Loss: 3.030e-03, SV Loss: 1.753e-03, Flow Loss: 1.277e-03, Time: 4.61
# Loss Improved, Saving Model
# It: 4550, Total Loss: 3.004e-03, SV Loss: 1.718e-03, Flow Loss: 1.286e-03, Time: 4.17
# Loss Improved, Saving Model
# It: 4600, Total Loss: 3.017e-03, SV Loss: 1.743e-03, Flow Loss: 1.274e-03, Time: 4.60
# It: 4650, Total Loss: 2.994e-03, SV Loss: 1.716e-03, Flow Loss: 1.278e-03, Time: 4.29
# Loss Improved, Saving Model
# It: 4700, Total Loss: 3.500e-03, SV Loss: 2.144e-03, Flow Loss: 1.355e-03, Time: 4.41
# It: 4750, Total Loss: 2.944e-03, SV Loss: 1.678e-03, Flow Loss: 1.266e-03, Time: 4.52
# Loss Improved, Saving Model
# It: 4800, Total Loss: 2.916e-03, SV Loss: 1.640e-03, Flow Loss: 1.276e-03, Time: 4.02
# Loss Improved, Saving Model
# It: 4850, Total Loss: 3.824e-03, SV Loss: 2.647e-03, Flow Loss: 1.177e-03, Time: 4.47
# It: 4900, Total Loss: 2.887e-03, SV Loss: 1.618e-03, Flow Loss: 1.269e-03, Time: 4.14
# Loss Improved, Saving Model
# It: 4950, Total Loss: 2.868e-03, SV Loss: 1.599e-03, Flow Loss: 1.269e-03, Time: 4.48
# Loss Improved, Saving Model
# It: 5000, Total Loss: 3.108e-03, SV Loss: 1.914e-03, Flow Loss: 1.193e-03, Time: 4.90
# It: 5050, Total Loss: 2.840e-03, SV Loss: 1.573e-03, Flow Loss: 1.266e-03, Time: 3.82
# Loss Improved, Saving Model
# It: 5100, Total Loss: 2.819e-03, SV Loss: 1.553e-03, Flow Loss: 1.266e-03, Time: 4.27
# Loss Improved, Saving Model
# It: 5150, Total Loss: 3.034e-03, SV Loss: 1.821e-03, Flow Loss: 1.213e-03, Time: 4.72
# It: 5200, Total Loss: 2.803e-03, SV Loss: 1.542e-03, Flow Loss: 1.261e-03, Time: 5.36
# Loss Improved, Saving Model
# It: 5250, Total Loss: 2.777e-03, SV Loss: 1.514e-03, Flow Loss: 1.263e-03, Time: 5.00
# Loss Improved, Saving Model
# It: 5300, Total Loss: 2.758e-03, SV Loss: 1.497e-03, Flow Loss: 1.262e-03, Time: 5.00
# Loss Improved, Saving Model
# It: 5350, Total Loss: 2.745e-03, SV Loss: 1.486e-03, Flow Loss: 1.258e-03, Time: 4.05
# Loss Improved, Saving Model
# It: 5400, Total Loss: 2.748e-03, SV Loss: 1.487e-03, Flow Loss: 1.261e-03, Time: 4.66
# It: 5450, Total Loss: 2.720e-03, SV Loss: 1.452e-03, Flow Loss: 1.268e-03, Time: 4.30
# Loss Improved, Saving Model
# It: 5500, Total Loss: 2.707e-03, SV Loss: 1.456e-03, Flow Loss: 1.250e-03, Time: 4.41
# Loss Improved, Saving Model
# It: 5550, Total Loss: 2.687e-03, SV Loss: 1.422e-03, Flow Loss: 1.265e-03, Time: 4.52
# Loss Improved, Saving Model
# It: 5600, Total Loss: 2.701e-03, SV Loss: 1.452e-03, Flow Loss: 1.249e-03, Time: 4.00
# It: 5650, Total Loss: 2.658e-03, SV Loss: 1.397e-03, Flow Loss: 1.261e-03, Time: 4.35
# Loss Improved, Saving Model
# It: 5700, Total Loss: 2.866e-03, SV Loss: 1.653e-03, Flow Loss: 1.213e-03, Time: 4.33
# It: 5750, Total Loss: 2.631e-03, SV Loss: 1.362e-03, Flow Loss: 1.269e-03, Time: 4.85
# Loss Improved, Saving Model
# It: 5800, Total Loss: 5.792e-03, SV Loss: 4.638e-03, Flow Loss: 1.154e-03, Time: 4.85
# It: 5850, Total Loss: 2.617e-03, SV Loss: 1.365e-03, Flow Loss: 1.253e-03, Time: 4.94
# Loss Improved, Saving Model
# It: 5900, Total Loss: 2.592e-03, SV Loss: 1.326e-03, Flow Loss: 1.266e-03, Time: 4.67
# Loss Improved, Saving Model
# It: 5950, Total Loss: 2.576e-03, SV Loss: 1.308e-03, Flow Loss: 1.268e-03, Time: 4.24
# Loss Improved, Saving Model
# It: 6000, Total Loss: 2.627e-03, SV Loss: 1.356e-03, Flow Loss: 1.270e-03, Time: 4.75
# It: 6050, Total Loss: 2.553e-03, SV Loss: 1.284e-03, Flow Loss: 1.269e-03, Time: 3.86
# Loss Improved, Saving Model
# It: 6100, Total Loss: 2.996e-03, SV Loss: 1.686e-03, Flow Loss: 1.310e-03, Time: 3.91
# It: 6150, Total Loss: 2.549e-03, SV Loss: 1.301e-03, Flow Loss: 1.248e-03, Time: 4.47
# Loss Improved, Saving Model
# It: 6200, Total Loss: 2.513e-03, SV Loss: 1.243e-03, Flow Loss: 1.270e-03, Time: 4.72
# Loss Improved, Saving Model
# It: 6250, Total Loss: 2.498e-03, SV Loss: 1.225e-03, Flow Loss: 1.273e-03, Time: 4.65
# Loss Improved, Saving Model
# It: 6300, Total Loss: 3.065e-03, SV Loss: 1.770e-03, Flow Loss: 1.295e-03, Time: 4.36
# It: 6350, Total Loss: 2.480e-03, SV Loss: 1.208e-03, Flow Loss: 1.272e-03, Time: 4.66
# Loss Improved, Saving Model
# It: 6400, Total Loss: 2.462e-03, SV Loss: 1.190e-03, Flow Loss: 1.272e-03, Time: 4.60
# Loss Improved, Saving Model
# It: 6450, Total Loss: 2.470e-03, SV Loss: 1.178e-03, Flow Loss: 1.291e-03, Time: 4.66
# It: 6500, Total Loss: 2.457e-03, SV Loss: 1.173e-03, Flow Loss: 1.285e-03, Time: 4.95
# Loss Improved, Saving Model
# It: 6550, Total Loss: 2.425e-03, SV Loss: 1.150e-03, Flow Loss: 1.275e-03, Time: 4.92
# Loss Improved, Saving Model
# It: 6600, Total Loss: 2.657e-03, SV Loss: 1.352e-03, Flow Loss: 1.305e-03, Time: 4.83
# It: 6650, Total Loss: 2.404e-03, SV Loss: 1.125e-03, Flow Loss: 1.279e-03, Time: 4.19
# Loss Improved, Saving Model
# It: 6700, Total Loss: 2.566e-03, SV Loss: 1.267e-03, Flow Loss: 1.300e-03, Time: 4.62
# It: 6750, Total Loss: 2.402e-03, SV Loss: 1.117e-03, Flow Loss: 1.285e-03, Time: 3.86
# Loss Improved, Saving Model
# It: 6800, Total Loss: 2.385e-03, SV Loss: 1.127e-03, Flow Loss: 1.258e-03, Time: 4.24
# Loss Improved, Saving Model
# It: 6850, Total Loss: 2.383e-03, SV Loss: 1.114e-03, Flow Loss: 1.270e-03, Time: 4.48
# Loss Improved, Saving Model
# It: 6900, Total Loss: 2.424e-03, SV Loss: 1.195e-03, Flow Loss: 1.229e-03, Time: 4.73
# It: 6950, Total Loss: 2.420e-03, SV Loss: 1.167e-03, Flow Loss: 1.253e-03, Time: 4.19
# It: 7000, Total Loss: 2.401e-03, SV Loss: 1.140e-03, Flow Loss: 1.260e-03, Time: 4.63
# It: 7050, Total Loss: 2.532e-03, SV Loss: 1.330e-03, Flow Loss: 1.202e-03, Time: 4.26
# It: 7100, Total Loss: 2.333e-03, SV Loss: 1.069e-03, Flow Loss: 1.264e-03, Time: 4.30
# Loss Improved, Saving Model
# It: 7150, Total Loss: 2.601e-03, SV Loss: 1.386e-03, Flow Loss: 1.215e-03, Time: 4.52
# It: 7200, Total Loss: 2.617e-03, SV Loss: 1.298e-03, Flow Loss: 1.319e-03, Time: 4.59
# It: 7250, Total Loss: 2.340e-03, SV Loss: 1.062e-03, Flow Loss: 1.278e-03, Time: 4.77
# It: 7300, Total Loss: 2.331e-03, SV Loss: 1.055e-03, Flow Loss: 1.276e-03, Time: 4.85
# Loss Improved, Saving Model
# It: 7350, Total Loss: 2.293e-03, SV Loss: 1.042e-03, Flow Loss: 1.251e-03, Time: 4.03
# Loss Improved, Saving Model
# It: 7400, Total Loss: 2.643e-03, SV Loss: 1.372e-03, Flow Loss: 1.271e-03, Time: 4.11
# It: 7450, Total Loss: 2.259e-03, SV Loss: 9.980e-04, Flow Loss: 1.261e-03, Time: 3.89
# Loss Improved, Saving Model
# It: 7500, Total Loss: 2.256e-03, SV Loss: 1.011e-03, Flow Loss: 1.245e-03, Time: 4.06
# Loss Improved, Saving Model
# It: 7550, Total Loss: 2.285e-03, SV Loss: 1.022e-03, Flow Loss: 1.263e-03, Time: 4.76
# It: 7600, Total Loss: 2.397e-03, SV Loss: 1.187e-03, Flow Loss: 1.210e-03, Time: 3.83
# It: 7650, Total Loss: 2.297e-03, SV Loss: 1.057e-03, Flow Loss: 1.239e-03, Time: 3.87
# It: 7700, Total Loss: 2.237e-03, SV Loss: 9.817e-04, Flow Loss: 1.255e-03, Time: 4.60
# Loss Improved, Saving Model
# It: 7750, Total Loss: 2.364e-03, SV Loss: 1.052e-03, Flow Loss: 1.312e-03, Time: 4.11
# It: 7800, Total Loss: 2.239e-03, SV Loss: 1.004e-03, Flow Loss: 1.235e-03, Time: 3.55
# It: 7850, Total Loss: 2.269e-03, SV Loss: 1.035e-03, Flow Loss: 1.235e-03, Time: 4.07
# It: 7900, Total Loss: 2.426e-03, SV Loss: 1.141e-03, Flow Loss: 1.285e-03, Time: 4.43
# It: 7950, Total Loss: 2.226e-03, SV Loss: 9.640e-04, Flow Loss: 1.262e-03, Time: 3.47
# Loss Improved, Saving Model
# It: 8000, Total Loss: 2.276e-03, SV Loss: 9.804e-04, Flow Loss: 1.296e-03, Time: 5.10
# It: 8050, Total Loss: 2.230e-03, SV Loss: 9.947e-04, Flow Loss: 1.235e-03, Time: 4.48
# It: 8100, Total Loss: 2.292e-03, SV Loss: 1.060e-03, Flow Loss: 1.231e-03, Time: 4.60
# It: 8150, Total Loss: 2.277e-03, SV Loss: 1.063e-03, Flow Loss: 1.214e-03, Time: 4.62
# It: 8200, Total Loss: 2.317e-03, SV Loss: 1.025e-03, Flow Loss: 1.292e-03, Time: 4.34
# It: 8250, Total Loss: 2.220e-03, SV Loss: 9.882e-04, Flow Loss: 1.232e-03, Time: 3.77
# Loss Improved, Saving Model
# It: 8300, Total Loss: 2.186e-03, SV Loss: 9.205e-04, Flow Loss: 1.266e-03, Time: 4.76
# Loss Improved, Saving Model
# It: 8350, Total Loss: 2.448e-03, SV Loss: 1.212e-03, Flow Loss: 1.236e-03, Time: 4.35
# It: 8400, Total Loss: 2.323e-03, SV Loss: 1.086e-03, Flow Loss: 1.238e-03, Time: 4.49
# It: 8450, Total Loss: 2.374e-03, SV Loss: 1.129e-03, Flow Loss: 1.245e-03, Time: 4.46
# It: 8500, Total Loss: 2.219e-03, SV Loss: 9.981e-04, Flow Loss: 1.221e-03, Time: 4.62
# It: 8550, Total Loss: 2.218e-03, SV Loss: 9.628e-04, Flow Loss: 1.255e-03, Time: 3.78
# It: 8600, Total Loss: 2.305e-03, SV Loss: 1.058e-03, Flow Loss: 1.247e-03, Time: 4.51
# It: 8650, Total Loss: 2.426e-03, SV Loss: 1.123e-03, Flow Loss: 1.303e-03, Time: 4.68
# It: 8700, Total Loss: 2.749e-03, SV Loss: 1.412e-03, Flow Loss: 1.337e-03, Time: 4.37
# It: 8750, Total Loss: 2.301e-03, SV Loss: 1.071e-03, Flow Loss: 1.230e-03, Time: 5.00
# It: 8800, Total Loss: 2.296e-03, SV Loss: 1.013e-03, Flow Loss: 1.283e-03, Time: 3.76
# It: 8850, Total Loss: 2.167e-03, SV Loss: 9.350e-04, Flow Loss: 1.232e-03, Time: 5.00
# Loss Improved, Saving Model
# It: 8900, Total Loss: 2.174e-03, SV Loss: 9.026e-04, Flow Loss: 1.271e-03, Time: 3.90
# It: 8950, Total Loss: 2.158e-03, SV Loss: 9.213e-04, Flow Loss: 1.237e-03, Time: 4.59
# Loss Improved, Saving Model
# It: 9000, Total Loss: 2.253e-03, SV Loss: 9.914e-04, Flow Loss: 1.262e-03, Time: 4.76
# It: 9050, Total Loss: 2.423e-03, SV Loss: 1.233e-03, Flow Loss: 1.190e-03, Time: 3.69
# It: 9100, Total Loss: 2.217e-03, SV Loss: 9.521e-04, Flow Loss: 1.265e-03, Time: 4.63
# It: 9150, Total Loss: 2.182e-03, SV Loss: 9.628e-04, Flow Loss: 1.219e-03, Time: 4.37
# It: 9200, Total Loss: 2.169e-03, SV Loss: 9.052e-04, Flow Loss: 1.264e-03, Time: 4.24
# It: 9250, Total Loss: 2.195e-03, SV Loss: 9.661e-04, Flow Loss: 1.229e-03, Time: 4.70
# It: 9300, Total Loss: 2.137e-03, SV Loss: 9.110e-04, Flow Loss: 1.226e-03, Time: 4.65
# Loss Improved, Saving Model
# It: 9350, Total Loss: 2.182e-03, SV Loss: 9.054e-04, Flow Loss: 1.277e-03, Time: 4.66
# It: 9400, Total Loss: 2.291e-03, SV Loss: 1.112e-03, Flow Loss: 1.178e-03, Time: 4.11
# It: 9450, Total Loss: 2.200e-03, SV Loss: 9.575e-04, Flow Loss: 1.242e-03, Time: 4.28
# It: 9500, Total Loss: 2.135e-03, SV Loss: 9.185e-04, Flow Loss: 1.217e-03, Time: 4.29
# Loss Improved, Saving Model
# It: 9550, Total Loss: 2.266e-03, SV Loss: 1.018e-03, Flow Loss: 1.248e-03, Time: 4.35
# It: 9600, Total Loss: 2.532e-03, SV Loss: 1.274e-03, Flow Loss: 1.258e-03, Time: 3.68
# It: 9650, Total Loss: 2.116e-03, SV Loss: 9.015e-04, Flow Loss: 1.215e-03, Time: 4.17
# Loss Improved, Saving Model
# It: 9700, Total Loss: 2.438e-03, SV Loss: 1.250e-03, Flow Loss: 1.188e-03, Time: 4.40
# It: 9750, Total Loss: 2.187e-03, SV Loss: 9.125e-04, Flow Loss: 1.274e-03, Time: 4.01
# It: 9800, Total Loss: 2.196e-03, SV Loss: 9.931e-04, Flow Loss: 1.203e-03, Time: 3.96
# It: 9850, Total Loss: 2.176e-03, SV Loss: 9.195e-04, Flow Loss: 1.256e-03, Time: 4.68
# It: 9900, Total Loss: 2.125e-03, SV Loss: 8.853e-04, Flow Loss: 1.240e-03, Time: 4.18
# It: 9950, Total Loss: 2.245e-03, SV Loss: 1.042e-03, Flow Loss: 1.203e-03, Time: 3.33

# %% [markdown]
# We can then plot the loss curves using:

# %%
plt.rcParams.update({'font.size': 25})
fig, (ax1, ax2,ax3) = plt.subplots(1,3, figsize=(30,10))
ax1.semilogy(loss_data_record, color = 'blue')
ax2.semilogy(loss_flows_record, color = 'red')
ax3.semilogy(loss_record, color = 'green')
ax1.set_title("$L_{SV}$ \n", size = 45)
ax2.set_title("$L_{FC}$ \n", size = 45)
ax3.set_title("$L_{TOTAL}$ \n", size = 45)

fig.supxlabel('Iteration', size = 40)
fig.supylabel('Loss \n', size = 40)
plt.tight_layout(pad=1)

# %% [markdown]
# ## Results
#
# Load in the model with the lowest loss, and then evaluate the trained model values on our grid:

# %%
model = torch.load("model_name.pt", weights_only=False) #Loading in 'Best Model'

#evaluating trained model values
u_theta_flat, u_phi_flat, div_flat, sv_flat, tg_flat, cond = PINNFlow(radius_tf, phi_tf, theta_tf,  horiz_theta_tf, horiz_phi_tf,br_tf, model).net_sv()
#detaching from cuda, converting to numpy, reshaping to original grid and removing 5 degree border
u_theta = -u_theta_flat.flatten().detach().numpy().reshape(Br_dot_data.shape)[5:-5, 5:-5]*10
u_phi = u_phi_flat.flatten().detach().numpy().reshape(Br_dot_data.shape)[5:-5, 5:-5]*10
sv_pred = sv_flat.flatten().detach().numpy().reshape(Br_dot_data.shape)[5:-5, 5:-5]*1e4

# %% [markdown]
# Checking the fit to the data:

# %%
#converting to nT/year
sv_nt = Br_dot_data[5:-5, 5:-5]*1e4
#calculating residual
res = sv_nt-sv_pred
rmse_sv = np.sqrt(mean_squared_error(sv_nt, sv_pred))
print("RMSE between CHAOS SV and Predicted SV = {0:.0f} nT/year.".format(rmse_sv))
permse = (rmse_sv*100)/np.abs(sv_nt).max()
print("Percentage RMSE between CHAOS SV and Predicted SV = {0:.2f}%.".format(permse))
# Out:
# RMSE between CHAOS SV and Predicted SV = 243 nT/year.
# Percentage RMSE between CHAOS SV and Predicted SV = 2.02%.

# %% [markdown]
# Plotting these results:

# %%
fig = plt.figure(figsize=(20, 20))
proj = ccrs.Mollweide() #ccrs.NearsidePerspective(central_latitude=90., central_longitude = 180)#
ax = plt.axes(projection=proj)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.COASTLINE)
plot2 = ax.quiver(phi_data[5:-5, 5:-5]*180/np.pi, 90-theta_data[5:-5, 5:-5]*180/np.pi, u_phi ,u_theta,color = 'black', transform=ccrs.PlateCarree())
ax.quiverkey(plot2, 0.8, 0.73, 20, label = '20 km/yr', labelpos='W',coordinates='figure',  fontproperties={'size':30})
ax.set_title("Recovered Flows \n", size = '30')
# Out:
# Text(0.5, 1.0, 'Recovered Flows \n')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(30,10))
plot1 = ax1.scatter(phi_data[5:-5, 5:-5]*180/np.pi, 90-theta_data[5:-5, 5:-5]*180/np.pi, c=sv_nt,cmap = 'bwr', s=200)
plot3 =ax2.scatter(phi_data[5:-5, 5:-5]*180/np.pi, 90-theta_data[5:-5, 5:-5]*180/np.pi, c=sv_pred,cmap = 'bwr', s=200)
plot4 =ax3.scatter(phi_data[5:-5, 5:-5]*180/np.pi, 90-theta_data[5:-5, 5:-5]*180/np.pi, c=res,cmap = 'bwr', vmin = -np.abs(res).max(), vmax = np.abs(res).max(), s=200)
plt.colorbar(plot1, ax = ax1, label = 'nT/year')
plt.colorbar(plot3, ax = ax2, label = 'nT/year')
plt.colorbar(plot4, ax = ax3, label = 'nT/year')
plt.tight_layout(pad=3)
ax1.set_title('"True" SV', fontsize = 25)
ax1.set_xlabel('Longitude', fontsize = 15)
ax1.set_ylabel('Latitude', fontsize = 15)

ax2.set_title('Output SV', fontsize = 25)
ax2.set_xlabel('Longitude', fontsize = 15)
ax2.set_ylabel('Latitude', fontsize = 15)

ax4.set_title('Residual SV, RMSE {0:.0f} nT/year.'.format(rmse_sv), fontsize = 25)
ax4.set_xlabel('Longitude', fontsize = 15)
ax4.set_ylabel('Latitude', fontsize = 15)
plt.suptitle("Input and Output SV, TG Assumption", fontsize = 40, y = 1.05)
# Out:
# Text(0.5, 1.05, 'Input and Output SV, TG Assumption')
